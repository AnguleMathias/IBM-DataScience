# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Introduction
# This notebook was created as part of the final project for the **IBM Tools for Data Science** course.
# It demonstrates basic Markdown formatting and Python coding in JupyterLab.

# %% [markdown]
# ## Data Science Languages
# Some of the popular languages used by data scientists are:
# 1. Python
# 2. R
# 3. JavaScript
# 4. C++

# %% [markdown]
# ## Data Science Libraries
# Here are some of the most commonly used libraries for data science:
# - **Pandas** – data manipulation and analysis
# - **NumPy** – numerical computations
# - **Matplotlib / Seaborn** – data visualization
# - **Scikit-learn** – machine learning
# - **TensorFlow / PyTorch** – deep learning frameworks

# %% [markdown]
# ## Data Science Tools
#
# | Tool                | Category            | Description |
# |----------------------|--------------------|--------------|
# | Jupyter Notebook     | IDE / Notebook     | Interactive environment for data science |
# | RStudio              | IDE                | R programming environment |
# | Apache Spark         | Big Data Framework | Large-scale data processing |
# | TensorFlow           | Deep Learning      | Neural network modeling |
# | IBM Watson Studio    | Cloud Platform     | AI & data science workspace |

# %% [markdown]
# ### Arithmetic Expression Examples
# Below are simple arithmetic examples performed in Python.

# %% [markdown]
# # Multiply and add numbers
# (5 * 4) + 3

# %% [markdown]
# # Convert minutes to hours
# minutes = 240
# hours = minutes / 60
# print(f"{minutes} minutes is equal to {hours} hours.")

# %% [markdown]
# ## Objectives
# The objectives of this notebook are:
# - Practice writing Markdown cells
# - Execute Python code within Jupyter Notebook
# - Format tables and lists
# - Demonstrate arithmetic operations
# - Share the notebook publicly via GitHub

# %% [markdown]
# ## Author
# **Mathias Lubutse Angule**
